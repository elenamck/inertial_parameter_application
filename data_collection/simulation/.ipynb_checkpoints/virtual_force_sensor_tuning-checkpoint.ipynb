# %% [markdown]
# # Imports

# %%
import numpy as np

# %%
cd ..
# Out:
# /Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application

# %%
from FunctionsAndObjects import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_file = "data_file_06-16-19_16-57-45"
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
time_2 = file[1::,0]
q_2 = file[1::,1:7]
dq_2 = file[1::,7:13]
force_virtual_2 = file[1::,13:16]
torque_virtual_2 = file[1::,16:19]
# double k_f_x = 1e5;
# 	double d_f_x = 900;

# 	double k_f_y = 1e5;
# 	double d_f_y = 800;
# 	double k_f_z = 1e5;
# 	double d_f_z = 900;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = "data_file_06-16-19_17-00-18"
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
time_3 = file[1::,0]
q_3 = file[1::,1:7]
dq_3 = file[1::,7:13]
force_virtual_3 = file[1::,13:16]
torque_virtual_3 = file[1::,16:19]
# 	double k_f_x = 1e5;
# 	double d_f_x = 2e3;

# 	double k_f_y = 1e5;
# 	double d_f_y = 800;
# 	double k_f_z = 1e5;
# 	double d_f_z = 2e3;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = "data_file_06-16-19_17-09-13"
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
time_4 = file[1::,0]
q_4 = file[1::,1:7]
dq_4 = file[1::,7:13]
force_virtual_4 = file[1::,13:16]
torque_virtual_4 = file[1::,16:19]
# 	double k_f_x = 1e5;
# 	double d_f_x = 2050;

# 	double k_f_y = 1e5;
# 	double d_f_y = 800;
# 	double k_f_z = 1e5;
# 	double d_f_z = 2e3;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = "data_file_06-16-19_17-15-43"
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
time_4 = file[1::,0]
q_4 = file[1::,1:7]
dq_4 = file[1::,7:13]
force_virtual_4 = file[1::,13:16]
torque_virtual_4 = file[1::,16:19]
# 	double k_f_x = 1e5;
# 	double d_f_x = 2050;

# 	double k_f_y = 1e5;
# 	double d_f_y = 800;
# 	double k_f_z = 2e5;
# 	double d_f_z = 1e4;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = "data_file_06-16-19_17-17-27"
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
time_5 = file[1::,0]
q_5 = file[1::,1:7]
dq_5 = file[1::,7:13]
force_virtual_5 = file[1::,13:16]
torque_virtual_5 = file[1::,16:19]

# 	double k_f_x = 1e5;
# 	double d_f_x = 2050;

# 	double k_f_y = 3e5;
# 	double d_f_y = 800;
# 	double k_f_z = 4e5;
# 	double d_f_z = 1e4;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = "data_file_06-16-19_14-39-21"
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
time = file[1::,0]
q = file[1::,1:7]
dq = file[1::,7:13]
force_virtual = file[1::,13:16]
torque_virtual = file[1::,16:19]

# %%
xyz_subplots_varinputs(prismatic_joint_info, ['k_f = 1e5, d_f = 650', 'k_f = 1e5, d_f = 650, k_if = 5', 'k_f = 1e5, d_f = 650', 'k_f = 1e5, d_f = 650'], q, q_2, q_3, q_4)

# %%
xyz_subplots_varinputs(revolute_joint_info, ['k_t = 1e3, d_t = 65', 'k_t = 5e4, d_t = 65'], q[2:6], q_2[2:6])
