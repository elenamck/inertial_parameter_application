# %% [markdown]
# # Imports

# %%
import numpy as np

# %%
cd ..
# Out:
# /Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application

# %%
from FunctionsAndObjects import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_file = "data_file_06-16-19_16-57-45"
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
time_2 = file[1::,0]
q_2 = file[1::,1:7]
dq_2 = file[1::,7:13]
force_virtual_2 = file[1::,13:16]
torque_virtual_2 = file[1::,16:19]
# double k_f_x = 1e5;
# 	double d_f_x = 900;

# 	double k_f_y = 1e5;
# 	double d_f_y = 800;
# 	double k_f_z = 1e5;
# 	double d_f_z = 900;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = "data_file_06-16-19_17-00-18"
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
time_3 = file[1::,0]
q_3 = file[1::,1:7]
dq_3 = file[1::,7:13]
force_virtual_3 = file[1::,13:16]
torque_virtual_3 = file[1::,16:19]
# 	double k_f_x = 1e5;
# 	double d_f_x = 2e3;

# 	double k_f_y = 1e5;
# 	double d_f_y = 800;
# 	double k_f_z = 1e5;
# 	double d_f_z = 2e3;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = "data_file_06-16-19_17-09-13"
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
time_4 = file[1::,0]
q_4 = file[1::,1:7]
dq_4 = file[1::,7:13]
force_virtual_4 = file[1::,13:16]
torque_virtual_4 = file[1::,16:19]
# 	double k_f_x = 1e5;
# 	double d_f_x = 2050;

# 	double k_f_y = 1e5;
# 	double d_f_y = 800;
# 	double k_f_z = 1e5;
# 	double d_f_z = 2e3;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = "data_file_06-16-19_17-15-43"
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
time_4 = file[1::,0]
q_4 = file[1::,1:7]
dq_4 = file[1::,7:13]
force_virtual_4 = file[1::,13:16]
torque_virtual_4 = file[1::,16:19]
# 	double k_f_x = 1e5;
# 	double d_f_x = 2050;

# 	double k_f_y = 1e5;
# 	double d_f_y = 800;
# 	double k_f_z = 2e5;
# 	double d_f_z = 1e4;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = "data_file_06-16-19_17-17-27"
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
time_5 = file[1::,0]
q_5 = file[1::,1:7]
dq_5 = file[1::,7:13]
force_virtual_5 = file[1::,13:16]
torque_virtual_5 = file[1::,16:19]

# 	double k_f_x = 1e5;
# 	double d_f_x = 2050;

# 	double k_f_y = 3e5;
# 	double d_f_y = 800;
# 	double k_f_z = 4e5;
# 	double d_f_z = 1e4;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = "data_file_06-16-19_17-21-10"
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
time_6 = file[1::,0]
q_6 = file[1::,1:7]
dq_6 = file[1::,7:13]
force_virtual_6 = file[1::,13:16]
torque_virtual_6 = file[1::,16:19]
# 	double k_f_x = 1e5;
# 	double d_f_x = 2050;

# 	double k_f_y = 5e5;
# 	double d_f_y = 800;
# 	double k_f_z = 4e5;
# 	double d_f_z = 6e4;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = 'data_file_06-16-19_17-26-22'
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
time_7 = file[1::,0]
q_7 = file[1::,1:7]
dq_7 = file[1::,7:13]
force_virtual_7 = file[1::,13:16]
torque_virtual_7 = file[1::,16:19]

# 	double k_f_x = 1e5;
# 	double d_f_x = 2050;

# 	double k_f_y = 6e5;
# 	double d_f_y = 800;
# 	double k_f_z = 6e5;
# 	double d_f_z = 1e4;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = 'data_file_06-16-19_17-33-37'
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
time_8 = file[1::,0]
q_8 = file[1::,1:7]
dq_8 = file[1::,7:13]
force_virtual_8 = file[1::,13:16]
torque_virtual_8 = file[1::,16:19]

# 	double k_f_x = 1e5;
# 	double d_f_x = 2050;

# 	double k_f_y = 7e5;
# 	double d_f_y = 800;
# 	double k_f_z = 7e5;
# 	double d_f_z = 1e4;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
xyz_subplots_varinputs(force_info,[' force_virtual_2', 'force_virtual_6','force_virtual_8'], force_virtual_2, force_virtual_6,force_virtual_8 )

# %%
xyz_subplots_varinputs(force_info,[' force_virtual_2', 'force_virtual_4', 'force_virtual_6','force_virtual_8'], force_virtual_2, force_virtual_4, force_virtual_6,force_virtual_8 )

# %%
data_file = 'data_file_06-16-19_17-52-53'
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
q_9 = file
# 	double k_f_x = 1e5;
# 	double d_f_x = 2050;

# 	double k_f_y = 9e5;
# 	double d_f_y = 800;
# 	double k_f_z = 9e5;
# 	double d_f_z = 1e4;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = 'data_file_06-16-19_17-56-52'
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
q_10 = file
# 	double k_f_x = 2e5;
# 	double d_f_x = 2050;

# 	double k_f_y = 9e5;
# 	double d_f_y = 800;
# 	double k_f_z = 9e5;
# 	double d_f_z = 1e4;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = 'data_file_06-16-19_18-06-47'
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
q_11 = file

# double k_f_x = 1e5;
# 	double d_f_x = 2050;

# 	double k_f_y = 9e5;
# 	double d_f_y = 800;
# 	double k_f_z = 9e5;
# 	double d_f_z = 1e4;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = 'data_file_06-16-19_18-13-40'
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
q_12 = file
# 	double k_f_x = 1e5;
# 	double d_f_x = 2050;

# 	double k_f_y = 9e5;
# 	double d_f_y = 900;
# 	double k_f_z = 9e5;
# 	double d_f_z = 2e4;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = 'data_file_06-16-19_18-28-29'
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
q_13 = file	
# # double k_f_x = 1e5;
# 	double d_f_x = 1500;

# 	double k_f_y = 9e5;
# 	double d_f_y = 850;
# 	double k_f_z = 9e5;
# 	double d_f_z = 2e3;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = "data_file_06-16-19_14-39-21"
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
time = file[1::,0]
q = file[1::,1:7]
dq = file[1::,7:13]
force_virtual = file[1::,13:16]
torque_virtual = file[1::,16:19]

# %%
data_file = 'data_file_06-16-19_18-36-04'
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
q_14 = file	
# 	double k_f_x = 1e5;
# 	double d_f_x = 1500;

# 	double k_f_y = 9e5;
# 	double d_f_y = 800;
# 	double k_f_z = 9e5;
# 	double d_f_z = 1e3;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = 'data_file_06-16-19_18-41-12'
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
q_15 = file
# double k_f_x = 1e5;
# 	double d_f_x = 1500;

# 	double k_f_y = 1e6;
# 	double d_f_y = 800;
# 	double k_f_z = 1e6;
# 	double d_f_z = 1e3;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = 'data_file_06-16-19_18-47-35'
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
q_16 = file	
# double k_f_x = 1e5;
# 	double d_f_x = 1500;

# 	double k_f_y = 1e6;
# 	double d_f_y = 700;
# 	double k_f_z = 1e6;
# 	double d_f_z = 900;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = 'data_file_06-16-19_18-59-47'
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
q_17 = file	
# double k_f_x = 1e5;
# 	double d_f_x = 1400;

# 	double k_f_y = 1e6;
# 	double d_f_y = 700;
# 	double k_f_z = 1e6;
# 	double d_f_z = 900;

# 	double k_t_x = 1e3;
# 	double d_t_x = 65;

# 	double k_t_y = 1e3;
# 	double d_t_y = 65;


# 	double k_t_z = 1e3;
# 	double d_t_z = 65;

# %%
data_file = 'data_file_06-16-19_20-22-17'
path = "/Users/elenakern/university/masters/sai-2/apps/inertial_parameter_application/data_collection/simulation/tuning/"
path_data_file = path + data_file
file = np.loadtxt(path_data_file, skiprows=1)
q_19 = file

# %%
prismatic_joint_info = Label("Prismatic joint displacement",'$p$', r"$[m]$")

# %%
def xyz_subplots_final(object_info, label_list, *datas):
    f, axarr = plt.subplots(3,1,figsize=(15,15))
    coordinates = ["$_x$","$_y$","$_z$"]
    color_list_aux = [red, green, blue, yellow, grey]
    for idx,ax in enumerate(axarr):
        for j, data in enumerate(datas):
            ax.plot(data[:,idx], c=color_list_aux[j], linewidth=2.0, label = label_list[j])
            ax.set_xlim(left=0)
            ax.set_ylabel(object_info.abbreviation +  str(coordinates[idx]) + ' ' + object_info.unit)
            ax.set_xlabel('time $[%macros]$')
            lines, labels = ax.get_legend_handles_labels()
            ax.grid(True)
            ax.legend(lines , labels , loc=0)
            ax.ticklabel_format(style='sci',scilimits=(-3,4),axis='both')
    f.tight_layout()

# %%
import matplotlib2tikz
# Out:
#   File "/usr/local/lib/python2.7/site-packages/matplotlib2tikz/save.py", line 256
#     def save(filepath, *args, encoding=None, **kwargs):
#                                      ^
# SyntaxError: invalid syntax

# %%
q.shape
# Out:
# (18931, 6)

# %%
xyz_subplots_final(prismatic_joint_info, ['k_f = 1e5, d_f = 650', 'k_f = 1e5, d_f = 650, k_if = 5', 'k_f = 1e5, d_f = 650', 'k_f = 1e5, d_f = 650',' '], q, q_2, q_3, q_19[20:,:],q_5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-167-ea6acb745953> in <module>()
#       1 xyz_subplots_final(prismatic_joint_info, ['k_f = 1e5, d_f = 650', 'k_f = 1e5, d_f = 650, k_if = 5', 'k_f = 1e5, d_f = 650', 'k_f = 1e5, d_f = 650',' '], q, q_2, q_3, q_19[20:,:],q_5)
# ----> 2 a
#
# NameError: name 'a' is not defined

# %%
 xyz_subplots_varinputs(prismatic_joint_info, ['q5', 'q6', 'q7','q_8','q_9'],q_5,q_6, q_7,q_8, q_9)

# %%
 xyz_subplots_varinputs(prismatic_joint_info, ['q_16', 'q_17', 'q_18'],  q_17, q_16, q_18)

# %%
 xyz_subplots_varinputs(prismatic_joint_info, ['q_10','q_11','q12', 'q_13','q_5', 'q_14'],q_10,q_11[20:,:], q_12, q_13, q_5,q_14)

# %%
xyz_subplots_varinputs(revolute_joint_info, ['k_t = 1e3, d_t = 65', 'k_t = 5e4, d_t = 65'], q[2:6], q_2[2:6])
